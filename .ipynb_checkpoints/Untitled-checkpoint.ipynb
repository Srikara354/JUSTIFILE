# %%
from flask import Flask, request, jsonify
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import pickle

# %%
app = Flask(__name__)

# %%
df['Description'] = df['Description'].fillna('  ')

# %%
# Load and train model
df = pd.read_csv("BNS_Self.csv")
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Description'])
y = df['BNS Section']

# %%
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
# Save the model and vectorizer
pickle.dump(model, open("model.pkl", "wb"))
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))

# %%
@app.route('/predict', methods=['POST'])
def predict():
    data = request.json['description']
    X_input = vectorizer.transform([data])
    prediction = model.predict(X_input)[0]
    return jsonify({"section": prediction})

# %%
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\keert\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
